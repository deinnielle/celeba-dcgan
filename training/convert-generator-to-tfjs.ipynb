# %%
from google.colab import drive
drive.mount('./mount')

# %%
# !pip install tensorflowjs

# %%
cd mount/My Drive/Colab Notebooks/celeba-dcgan/models/

# %%
# !tensorflowjs_converter --input_format keras --output_format tfjs_layers_model generator-100.h5 ./tfjs-generator-100
