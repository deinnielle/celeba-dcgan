# %%
import imageio
import glob

# %%
from google.colab import drive
drive.mount('./mount/')

# %%
with imageio.get_writer('mount/My Drive/Colab Notebooks/celeba-dcgan/celeba-dcgan.gif', mode='I') as writer:
  filenames = glob.glob('mount/My Drive/Colab Notebooks/celeba-dcgan/progress/generator-*')
  for filename in filenames:
    image = imageio.imread(filename)
    writer.append_data(image)
